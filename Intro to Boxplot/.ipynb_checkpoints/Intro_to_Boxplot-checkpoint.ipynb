# %% [markdown]
# # ``Box Plot``

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nba=pd.read_csv('nba.csv')
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba['Height']= nba['Height'].str.replace('-','.')
nba['Height']=nba['Height'].astype(float)
nba['Height']
# Out:
# 0      6.2
# 1      6.6
# 2      6.5
# 3      6.5
# 4      6.1
#       ...
# 453    6.3
# 454    6.1
# 455    7.3
# 456    7.0
# 457    NaN
# Name: Height, Length: 458, dtype: float64

# %%
nba.isna().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
def find_outliers(series):
    q1=series.describe()['25%']
    q2=series.describe()['50%']
    q3=series.describe()['75%']
    iqr=q3-q1
    lower_bound=q1-(1.5*iqr)
    upper_bound=q3+(1.5*iqr)
    outliers=[i for i in series if i<lower_bound or i>upper_bound]
    return outliers

# %%
print(find_outliers(nba['Salary']))
# Out:
# [19689000.0, 22875000.0, 15501000.0, 18907726.0, 19689000.0, 21468695.0, 25000000.0, 15592217.0, 15851950.0, 16407500.0, 20093064.0, 16407501.0, 22970500.0, 19689000.0, 16000000.0, 17120106.0, 14700000.0, 16407500.0, 16407500.0, 15361500.0, 15756438.0, 22359364.0, 19688000.0, 15514031.0, 19689000.0, 16407500.0, 18671659.0, 22192730.0, 14783000.0, 20000000.0, 15851950.0, 20158622.0, 16407500.0, 16744218.0, 15409570.0]

# %%
nba['Salary'].min()
# Out:
# 30888.0

# %%
outlier_salary=find_outliers(nba['Salary'])

# %%
nba[nba['Salary'].isin(outlier_salary)].sort_values('Salary')
# Out:
#                   Name                   Team  Number Position   Age  Height  \
# 219    Khris Middleton        Milwaukee Bucks    22.0       SG  24.0    6.80
# 341       Goran Dragic             Miami Heat     7.0       PG  30.0    6.30
# 238   Chandler Parsons       Dallas Mavericks    25.0       SF  27.0    6.10
# 448     Gordon Hayward              Utah Jazz    20.0       SF  26.0    6.80
# 89       Klay Thompson  Golden State Warriors    11.0       SG  26.0    6.70
# 288        Eric Gordon   New Orleans Pelicans    10.0       SG  27.0    6.40
# 111        Roy Hibbert     Los Angeles Lakers    17.0        C  29.0    7.20
# 249       James Harden        Houston Rockets    13.0       SG  26.0    6.50
# 382          John Wall     Washington Wizards     2.0       PG  25.0    6.40
# 143   DeMarcus Cousins       Sacramento Kings    15.0        C  25.0    6.11
# 189      Tobias Harris        Detroit Pistons    34.0       SF  23.0    6.90
# 418        Enes Kanter  Oklahoma City Thunder    11.0        C  24.0    6.11
# 301      Kawhi Leonard      San Antonio Spurs     2.0       SF  24.0    6.70
# 233    Wesley Matthews       Dallas Mavericks    23.0       SG  29.0    6.50
# 220        Greg Monroe        Milwaukee Bucks    15.0        C  26.0    6.11
# 153       Jimmy Butler          Chicago Bulls    21.0       SG  26.0    6.70
# 168       Kyrie Irving    Cleveland Cavaliers     2.0       PG  24.0    6.30
# 426  Russell Westbrook  Oklahoma City Thunder     0.0       PG  27.0    6.30
# 199        Paul George         Indiana Pacers    13.0       SF  26.0    6.90
# 315       Paul Millsap          Atlanta Hawks     4.0       PF  31.0    6.80
# 96       Blake Griffin   Los Angeles Clippers    32.0       PF  27.0    6.10
# 265         Marc Gasol      Memphis Grizzlies    33.0        C  31.0    7.10
# 98      DeAndre Jordan   Los Angeles Clippers     6.0        C  27.0    6.11
# 174         Kevin Love    Cleveland Cavaliers     0.0       PF  27.0    6.10
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0    6.11
# 23         Brook Lopez          Brooklyn Nets    11.0        C  28.0    7.00
# 349        Dwyane Wade             Miami Heat     3.0       SG  34.0    6.40
# 164       Derrick Rose          Chicago Bulls     1.0       PG  27.0    6.30
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6.90
# 100         Chris Paul   Los Angeles Clippers     3.0       PG  31.0    6.00
# 339         Chris Bosh             Miami Heat     1.0       PF  32.0    6.11
# 251      Dwight Howard        Houston Rockets    12.0        C  30.0    6.11
# 33     Carmelo Anthony        New York Knicks     7.0       SF  32.0    6.80
# 169       LeBron James    Cleveland Cavaliers    23.0       SF  31.0    6.80
# 109        Kobe Bryant     Los Angeles Lakers    24.0       SF  37.0    6.60
#
#      Weight           College      Salary
# 219   234.0         Texas A&M  14700000.0
# 341   190.0               NaN  14783000.0
# 238   230.0           Florida  15361500.0
# 448   226.0            Butler  15409570.0
# 89    215.0  Washington State  15501000.0
# 288   215.0           Indiana  15514031.0
# 111   270.0        Georgetown  15592217.0
# 249   220.0     Arizona State  15756438.0
# 382   195.0          Kentucky  15851950.0
# 143   270.0          Kentucky  15851950.0
# 189   235.0         Tennessee  16000000.0
# 418   245.0          Kentucky  16407500.0
# 301   230.0   San Diego State  16407500.0
# 233   220.0         Marquette  16407500.0
# 220   265.0        Georgetown  16407500.0
# 153   220.0         Marquette  16407500.0
# 168   193.0              Duke  16407501.0
# 426   200.0              UCLA  16744218.0
# 199   220.0      Fresno State  17120106.0
# 315   246.0    Louisiana Tech  18671659.0
# 96    251.0          Oklahoma  18907726.0
# 265   255.0               NaN  19688000.0
# 98    265.0         Texas A&M  19689000.0
# 174   251.0              UCLA  19689000.0
# 294   240.0             Texas  19689000.0
# 23    275.0          Stanford  19689000.0
# 349   220.0         Marquette  20000000.0
# 164   190.0           Memphis  20093064.0
# 414   240.0             Texas  20158622.0
# 100   175.0       Wake Forest  21468695.0
# 339   235.0      Georgia Tech  22192730.0
# 251   265.0               NaN  22359364.0
# 33    240.0          Syracuse  22875000.0
# 169   250.0               NaN  22970500.0
# 109   212.0               NaN  25000000.0

# %%
nba.boxplot('Salary')

# %%
plt.figure(figsize=(7,5))
plt.boxplot(nba['Salary'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1239: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1246: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1254: RuntimeWarning: invalid value encountered in less
#   x[x < stats['whislo']],
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1255: RuntimeWarning: invalid value encountered in greater
#   x[x > stats['whishi']],
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f042563760>,
#   <matplotlib.lines.Line2D at 0x1f042563910>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f042563c70>,
#   <matplotlib.lines.Line2D at 0x1f042563fd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f042563400>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f04259a370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f04259a670>],
#  'means': []}
